# %% [markdown]
# # 不要迷信默认设置

# %% [markdown]
# 导入相关的包：

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 生成三角函数：

# %%
x = np.linspace(-np.pi,np.pi)
c, s = np.cos(x), np.sin(x)

# %% [markdown]
# ## 默认绘图

# %%
p = plt.plot(x,c)
p = plt.plot(x,s)

# %% [markdown]
# 默认效果如图所示，我们可以修改默认的属性来得到更漂亮的结果。

# %% [markdown]
# # 图

# %% [markdown]
# 图像以 `Figure #` 为窗口标题，并且数字从 1 开始，`figure()` 函数的主要参数如下：
#
# 参数 | 默认值 | 描述
# ---|---|---
# `num`|`1`| 图号
# `figsize`|`figure.figsize`| 图大小（宽，高）（单位英寸）
# `dpi`|`figure.dpi`| 分辨率（每英寸所打印的点数）
# `facecolor`|`figure.facecolor`| 背景颜色
# `edgecolor`|`figure.edgecolor`| 边界颜色
# `frameon` |`True`| 是否显示图框架

# %%
f = plt.figure(figsize=(10,6), dpi=80)
p = plt.plot(x,c, x,s)

# %% [markdown]
# ### 设置线条颜色，粗细，类型

# %% [markdown]
# 首先，我们使用 figure() 函数来创建一幅新图像，并且指定它的大小，使得长宽比更合适。
#
# 然后，我们使用 `color, linewidth, linestyle` 参数，指定曲线的颜色，粗细，类型：

# %%
f = plt.figure(figsize=(10,6), dpi=80)
p = plt.plot(x,c, color='b', lw=2.5, ls='-')
p = plt.plot(x,s, color='r', lw=2.5, ls='-')

# %% [markdown]
# 也可以像 **Matlab** 中一样使用格式字符来修改参数：
#
# 表示颜色的字符参数有：
#
# 字符 | 颜色
# -- | --
# `‘b’`|	蓝色，blue
# `‘g’`|	绿色，green
# `‘r’`|	红色，red
# `‘c’`|	青色，cyan
# `‘m’`|	品红，magenta
# `‘y’`|	黄色，yellow
# `‘k’`|	黑色，black
# `‘w’`|	白色，white
#
# 表示类型的字符参数有：
#
# 字符|类型 | 字符|类型
# ---|--- | --- | ---
# `  '-'	`| 实线 | `'--'`|	虚线
# `'-.'`|	虚点线 | `':'`|	点线
# `'.'`|	点 | `','`| 像素点
# `'o'`	|圆点 | `'v'`|	下三角点
# `'^'`|	上三角点 | `'<'`|	左三角点
# `'>'`|	右三角点 | `'1'`|	下三叉点
# `'2'`|	上三叉点 | `'3'`|	左三叉点
# `'4'`|	右三叉点 | `'s'`|	正方点
# `'p'`	| 五角点 | `'*'`|	星形点
# `'h'`|	六边形点1 | `'H'`|	六边形点2
# `'+'`|	加号点 | `'x'`|	乘号点
# `'D'`|	实心菱形点 | `'d'`|	瘦菱形点
# `'_'`|	横线点 | |

# %%
f = plt.figure(figsize=(10,6), dpi=80)
p = plt.plot(x,c, 'b-', x,s, 'r-', lw=2.5)

# %% [markdown]
# ### 设置横轴纵轴的显示区域

# %% [markdown]
# 我们希望将坐标轴的显示区域放大一些，这样可以看到所有的点，可以使用 `plt` 中的 `xlim` 和 `ylim` 来设置：

# %%
f = plt.figure(figsize=(10,6), dpi=80)
p = plt.plot(x,c, 'b-', x,s, 'r-', lw=2.5)
p = plt.xlim(x.min()*1.1, x.max()*1.1)
p = plt.ylim(c.min()*1.1, c.max()*1.1)

# %% [markdown]
# ### 设置刻度

# %% [markdown]
# 对于三教函数来说，我们希望将 `x` 轴的刻度设为与 $\pi$ 有关的点，可以使用 `plt` 中的 `xticks` 和 `yticks` 函数，将需要的刻度传入：

# %%
f = plt.figure(figsize=(10,6), dpi=80)

p = plt.plot(x,c, 'b-', x,s, 'r-', lw=2.5)

p = plt.xlim(x.min()*1.1, x.max()*1.1)
p = plt.ylim(c.min()*1.1, c.max()*1.1)

p = plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
p = plt.yticks([-1,0,1])

# %% [markdown]
# ### 设定 x 轴 y 轴标题

# %% [markdown]
# 我们想让刻度的位置显示的是含有 $\pi$ 的标识而不是浮点数，可以在 `xticks` 中传入第二组参数，这组参数代表对应刻度的显示标识。这里，我们使用 `latex` 的语法来显示特殊符号（使用 `$$` 包围的部分）：

# %%
f = plt.figure(figsize=(10,6), dpi=80)

p = plt.plot(x,c, 'b-', x,s, 'r-', lw=2.5)

p = plt.xlim(x.min()*1.1, x.max()*1.1)
p = plt.ylim(c.min()*1.1, c.max()*1.1)

p = plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
               ['$-\pi$', '$-\pi/2$', '$0$', '$\pi/2$', '$\pi$'])
p = plt.yticks([-1,0,1], ['$-1$', '$0$', '$1$'])

# %% [markdown]
# ### 移动坐标轴的位置

# %% [markdown]
# 现在坐标轴的位置是在边界上，而且有上下左右四条，我们现在想将下面和左边的两条移动到中间，并将右边和上面的两条去掉：

# %%
f = plt.figure(figsize=(10,6), dpi=80)

p = plt.plot(x,c, 'b-', x,s, 'r-', lw=2.5)

p = plt.xlim(x.min()*1.1, x.max()*1.1)
p = plt.ylim(c.min()*1.1, c.max()*1.1)

##################################################################
ax = plt.gca() # 得到轴的句柄
ax.spines['right'].set_color('none') # 坐标轴右侧设置为透明
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom') # 将x轴的刻度设置在下面的坐标轴
ax.spines['bottom'].set_position(('data', 0)) # 设置x轴位置
ax.yaxis.set_ticks_position('left') # 将x轴的刻度设置在下面的坐标轴
ax.spines['left'].set_position(('data', 0)) # 设置x轴位置
##################################################################

p = plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
               ['$-\pi$', '$-\pi/2$', '$0$', '$\pi/2$', '$\pi$'])
p = plt.yticks([-1,0,1], ['$-1$', '$0$', '$1$'])

# %% [markdown]
# ### 加入图例

# %% [markdown]
# 使用 legend() 加入图例：

# %%
f = plt.figure(figsize=(10,6), dpi=80)

p = plt.plot(x,c, 'b-', x,s, 'r-', lw=2.5)

p = plt.xlim(x.min()*1.1, x.max()*1.1)
p = plt.ylim(c.min()*1.1, c.max()*1.1)

##################################################################
ax = plt.gca() # 得到轴的句柄
ax.spines['right'].set_color('none') # 坐标轴右侧设置为透明
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom') # 将x轴的刻度设置在下面的坐标轴
ax.spines['bottom'].set_position(('data', 0)) # 设置x轴位置
ax.yaxis.set_ticks_position('left') # 将x轴的刻度设置在下面的坐标轴
ax.spines['left'].set_position(('data', 0)) # 设置x轴位置
##################################################################

p = plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
               ['$-\pi$', '$-\pi/2$', '$0$', '$\pi/2$', '$\pi$'])
p = plt.yticks([-1,0,1], ['$-1$', '$0$', '$1$'])

plt.legend(['cosine', 'sine'], loc='upper left', frameon=False) # 去掉图例边框

# %% [markdown]
# ### 注释特殊点

# %% [markdown]
# 我们可以使用 `annotate` 函数来注释特殊的点，假设我们要显示的点是 $2\pi/3$：

# %%
f = plt.figure(figsize=(10,6), dpi=80)

p = plt.plot(x,c, 'b-', x,s, 'r-', lw=2.5)

p = plt.xlim(x.min()*1.1, x.max()*1.1)
p = plt.ylim(c.min()*1.1, c.max()*1.1)


############################## 坐标轴 ##############################
ax = plt.gca() # 得到轴的句柄
ax.spines['right'].set_color('none') # 坐标轴右侧设置为透明
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom') # 将x轴的刻度设置在下面的坐标轴
ax.spines['bottom'].set_position(('data', 0)) # 设置x轴位置
ax.yaxis.set_ticks_position('left') # 将x轴的刻度设置在下面的坐标轴
ax.spines['left'].set_position(('data', 0)) # 设置x轴位置
##################################################################

p = plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
               ['$-\pi$', '$-\pi/2$', '$0$', '$\pi/2$', '$\pi$'])
p = plt.yticks([-1,0,1], ['$-1$', '$0$', '$1$'])

plt.legend(['cosine', 'sine'], loc='upper left', frameon=False) # 去掉图例边框

############################ 数据点 ################################
t = 2*np.pi/3
plt.plot([t,t], [0,np.cos(t)], color='b', lw=2.5, ls='--') # x轴到该点虚线
plt.scatter(t,np.cos(t), 50, color='b')
plt.annotate(r'$cos(\frac{2\pi}{3})=\frac{1}{2}$',
             xy=(t, np.cos(t)), xycoords='data', xytext=(-90, -50),
             textcoords='offset points', fontsize=16,
             arrowprops={'arrowstyle':'->', 'connectionstyle':'arc3, rad=0.2'})

plt.plot([t,t], [0,np.sin(t)], color='r', lw=2.5, ls='--') # x轴到该点虚线
plt.scatter(t,np.sin(t), 50, color='r')
plt.annotate(r'$sin(\frac{2\pi}{3})=\frac{1}{2}$',
             xy=(t, np.sin(t)), xycoords='data', xytext=(10, 30),
             textcoords='offset points', fontsize=16,
             arrowprops={'arrowstyle':'->', 'connectionstyle':'arc3, rad=0.2'})
##################################################################
# Out:
# Text(10, 30, '$sin(\\frac{2\\pi}{3})=\\frac{1}{2}$')

# %% [markdown]
# ### 最后调整

# %% [markdown]
# 调整刻度值的大小，并让其显示在曲线上方。

# %%
f = plt.figure(figsize=(10,6), dpi=80)

p = plt.plot(x,c, 'b-', x,s, 'r-', lw=2.5)

p = plt.xlim(x.min()*1.1, x.max()*1.1)
p = plt.ylim(c.min()*1.1, c.max()*1.1)

############################## 坐标轴 ##############################
ax = plt.gca() # 得到轴的句柄
ax.spines['right'].set_color('none') # 坐标轴右侧设置为透明
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom') # 将x轴的刻度设置在下面的坐标轴
ax.spines['bottom'].set_position(('data', 0)) # 设置x轴位置
ax.yaxis.set_ticks_position('left') # 将x轴的刻度设置在下面的坐标轴
ax.spines['left'].set_position(('data', 0)) # 设置x轴位置
##################################################################

p = plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
               ['$-\pi$', '$-\pi/2$', '$0$', '$\pi/2$', '$\pi$'])
p = plt.yticks([-1,0,1], ['$-1$', '$0$', '$1$'])

plt.legend(['cosine', 'sine'], loc='upper left', frameon=False) # 去掉图例边框

############################ 数据点 ################################
t = 2*np.pi/3
plt.plot([t,t], [0,np.cos(t)], color='b', lw=2.5, ls='--') # x轴到该点虚线
plt.scatter(t,np.cos(t), 50, color='b')
plt.annotate(r'$cos(\frac{2\pi}{3})=\frac{1}{2}$',
             xy=(t, np.cos(t)), xycoords='data', xytext=(-90, -50),
             textcoords='offset points', fontsize=16,
             arrowprops={'arrowstyle':'->', 'connectionstyle':'arc3, rad=0.2'})

plt.plot([t,t], [0,np.sin(t)], color='r', lw=2.5, ls='--') # x轴到该点虚线
plt.scatter(t,np.sin(t), 50, color='r')
plt.annotate(r'$sin(\frac{2\pi}{3})=\frac{1}{2}$',
             xy=(t, np.sin(t)), xycoords='data', xytext=(10, 30),
             textcoords='offset points', fontsize=16,
             arrowprops={'arrowstyle':'->', 'connectionstyle':'arc3, rad=0.2'})
##################################################################

for label in ax.get_xticklabels() + ax.get_yticklabels(): # 没有起作用
    label.set_fontsize(16)
    label.set_bbox({'facecolor':'white', 'edgecolor':'None', 'alpha':0.65})

# %% [markdown]
# > The devil is in the details.
